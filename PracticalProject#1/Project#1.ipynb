# %% [markdown]
# <div style="direction:rtl;line-height:250%;">
# 	<font face="Estedad" size=5>
# 		<div align=center style="margin-top: 100px;">
# 			<font face="Estedad Semibold" size=20>
# 				<p></p>
# به نام خدا
# 				<p></p>
# 			</font>
# <font color=2d2d2e>
# آمار و احتمال مهندسی
#             </font>
#             <br />
# 			<font color=#616161 size = 3>
# دانشگاه صنعتی شریف - دانشکده مهندسی کامپیوتر
#             </font>
# 			<p></p>
# پاییز 1401
# 		</div>		<hr/>
# 		<div align=center>
# 		    <font color=#ed1564 face="Estedad SemiBold">
# 			    <br />
# پروژه عملی فاز یک
#             	<br/>
# 			</font>
# <font color=#616161 face="Estedad Light" size = 4>
# طراح: سجاد سلطانیان
# 			<br/>
# موعد تحویل: 7 بهمن‌ماه
#
# <br/><br/>
# </font>
#                 همفکری در تمامی مراحل پروژه توصیه می‌شود. در عین حال از شما خواسته می‌شود تا تمام پیاده‌سازی را به تنهایی و بدون مشاهده کد دیگران انجام دهید.
#                 <br/><br/>
#                 <font color=#ed1564>
#                 لطفا در فایل ارسالی تمام بلوک‌های کد اجرا شده و شامل نمودار‌ها و خروجی‌های لازم باشند.
#      </font>
#                 <br/>
#         </style>
# 	</font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="Estedad Semibold" size=5>
# 		<font color=black size=6 >
#              مقدمه
#         </font>
#         <hr/>
#         <div dir = "rtl" style="direction:rtl;line-height:150%; textAlign: right">
# 	<font face="Estedad" size=4 color=#2d2d2e>
#           هدف از این تمرین، آشنایی با مقدمات زبان برنامه‌نویسی R در قالب کاربردی است. در هر بخش با بیان دقیق خواسته  مسئله سعی شده است تا از هرگونه ابهام پیشگیری شود. با این حال، چنانچه در فهم خواسته سوال ابهامی وجود داشت در بستر کوئرا بیان کنید تا پاسخ داده شود.
#         <br>
# <div style="margin: 10px 0; border-radius: 8px;padding: 15px; background-color: #fff2b2; color: #7c620c; ">
#         توجه: ممکن است برای رسیدن به پاسخ، راه‌های متعددی وجود داشته باشد. پاسخ شما تا زمانی که خواسته مسئله را برآورده کند کاملا قابل قبول خواهد بود.
#     </div>
# </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="Estedad Semibold" size=5>
# 		<font color=black size=6>
#             محتوای دادگان
#         </font>
#         <hr/>
#                 <div dir = "rtl" style="direction:rtl;line-height:150%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
#     دادگانی که در اختیار شما قرار گرفته است (فایل book.csv) مجموعه دادگان واقعی از کتاب‌هاست که توسط سایت GoodReads منتشر شده است. در ادامه به توضیح مختصر ستون‌های این مجموعه‌داده می‌پردازیم:
#
# <br>
# <ul>
# <li>Title: عنوان کتاب</li>
# <li>Series: چنانچه کتاب به صورت چند جلدی یا چند قسمتی باشد، نام مجموعه آن در این بخش خواهد بود</li>
# <li>Author: نویسنده یا نویسندگان به تفکیک (با کاما جدا شده‌اند)</li>
# <li>Rating: امتیاز نظرسنجی (مقیاس ۰ تا ۵)</li>
# <li>Language: زبان</li>
# <li>Genres: لیست ‌دسته‌بندی‌هایی که کتاب در آن قرار می‌گیرد</li>
# <li>Pages: تعداد صفحات</li>
# <li>Publisher: ناشر</li>
# <li>Publish year: سال انتشار</li>
# <li>NumRating: تعداد رای‌ها</li>
# <li>LikedPercent: درصد علاقه خریداران به کتاب</li>
# <li>Price: قیمت کتاب به دلار</li>
# </ul>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="Estedad Semibold" size=5>
# 		<font color=black size=6>
#             کتابخانه‌ها
#         </font>
#         <hr/>
#                 <div dir = "rtl" style="direction:rtl;line-height:150%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
#     در طول این فرایند از کتابخانه‌های زیر استفاده خواهیم کرد. اما  همانطور که پیشتر بیان شد لزومی به استفاده از این کتابخانه‌ها نیست و استفاده از هر کتابخانه دلخواه  دیگری (تا زمانی که خواسته مسئله برآورده شود) مورد قبول است.
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۱ امتیاز</span>
# </font>
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ast
import collections
from wordcloud import WordCloud
import math

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="Estedad Semibold" size=5>
# 		<font color=black size=6>
#             مطالعه و آنالیز دادگان
#         </font>
#         <hr/>
#                 <div dir = "rtl" style="direction:rtl;line-height:150%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
#     در این بخش می‌خواهیم به روش‌ّهای مختلف به مطالعه و بررسی ویژگی‌ها و ارتباطات بین آن‌ها در این مجموعه داده بپردازیم. همچنین در هر گام از مسیر پیش رو سعی کرده‌ایم که دلایل اهمیت فرایند EDA را در علوم دیگر و به خصوص هوش مصنوعی و یادگیری ماشین به طور ضمنی بیان کنیم.
# </font>
#
# <font color=black size=5>
#     <br><br>
# بارگذاری داده‌ها
# </font>
#
# <br>
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
#     در این بخش می‌خواهیم به روش‌ّهای مختلف به مطالعه و بررسی ویژگی‌ها و ارتباطات بین آن‌ها در این مجموعه داده بپردازیم. همچنین در هر گام از مسیر پیش رو سعی کرده‌ایم که دلایل اهمیت فرایند EDA را در علوم دیگر و به خصوص هوش مصنوعی و یادگیری ماشین به طور ضمنی بیان کنیم.
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۱ امتیاز</span>
# </font>
#
# </div>

# %%
# code here
dataframe = pd.read_csv('files/books.csv')

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
#  <font face="Estedad Semibold" size=5>
#
# <font color=black size=5>
# نیم‌نگاه
# </font>
#
# <br>
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# همواره پس از لود اولیه دادگان، به بررسی اجمالی و آشنایی کلی با داده‌ می‌پردازیم که در ادامه، این کار را به روش‌های مختلف انجام خواهیم داد.
# <br>
# <strong>Shape</strong>: شکل کلی دیتاست، یعنی تعداد سطر و ستون‌ آن را نمایش دهید.
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۱ امتیاز</span>
# </font>
# </font>
# </div>

# %%
# code here
rows=dataframe.shape[0]
columns=dataframe.shape[1]
print("Rows={}\nColumns={}\n".format(rows,columns))
# Out:
# Rows=10915
# Columns=12

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# <strong>Preview</strong>: به عنوان پیش‌نمایش، ۳ سطر ابتدایی و ۳ سطر انتهایی دیتاست را چاپ کنید. <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۱ امتیاز</span>
# </font>
# </div>

# %%
# code here
print("The 3 first rows:")
display(dataframe.iloc[0:3])
print("The 3 last rows:")
display(dataframe.iloc[rows-3:rows])
# Out:
# The 3 first rows:
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
#
#                                       author  rating language  \
# 0                            Suzanne Collins    4.33  English
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50  English
# 2                                 Harper Lee    4.28  English
#
#                                               genres  pages  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...    374
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...    870
# 2  ['Classics', 'Fiction', 'Historical Fiction', ...    324
#
#                           publisher  publish year  numRatings  likedPercent  \
# 0                  Scholastic Press          2008     6376780            96
# 1                   Scholastic Inc.          2004     2507623            98
# 2  Harper Perennial Modern Classics          2006     4501075            95
#
#   price
# 0  5.09
# 1  7.38
# 2   NaN
# The 3 last rows:
#                                              title series  \
# 10912                             Shy Green Fields    NaN
# 10913  An A - Z of Looney Limericks (for big kids)    NaN
# 10914                                     Fragment    NaN
#
#                                                   author  rating language  \
# 10912             Hugh Behm-Steinberg (Goodreads Author)    4.70  English
# 10913  Bernie Morris (Goodreads Author), Linda Kopers...    4.85  English
# 10914                                         Lars Norén    3.39  Swedish
#
#            genres  pages               publisher  publish year  numRatings  \
# 10912  ['Poetry']    116           No Tell Books          2007          33
# 10913  ['Poetry']    124        Bronwyn Editions          2009          33
# 10914  ['Poetry']    541  Albert Bonniers Förlag          2015          23
#
#        likedPercent price
# 10912           100  13.1
# 10913           100  2.48
# 10914            83   NaN

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# <strong>Preview</strong>: به عنوان پیش‌نمایش، ۳ سطر ابتدایی و ۳ سطر انتهایی دیتاست را چاپ کنید. <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۱ امتیاز</span>
# </font>
# </div>

# %%
# code here
print("The 3 first rows:")
display(dataframe.iloc[0:3])
print("The 3 last rows:")
display(dataframe.iloc[rows-3:rows])
# Out:
# The 3 first rows:
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
#
#                                       author  rating language  \
# 0                            Suzanne Collins    4.33  English
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50  English
# 2                                 Harper Lee    4.28  English
#
#                                               genres  pages  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...    374
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...    870
# 2  ['Classics', 'Fiction', 'Historical Fiction', ...    324
#
#                           publisher  publish year  numRatings  likedPercent  \
# 0                  Scholastic Press          2008     6376780            96
# 1                   Scholastic Inc.          2004     2507623            98
# 2  Harper Perennial Modern Classics          2006     4501075            95
#
#   price
# 0  5.09
# 1  7.38
# 2   NaN
# The 3 last rows:
#                                              title series  \
# 10912                             Shy Green Fields    NaN
# 10913  An A - Z of Looney Limericks (for big kids)    NaN
# 10914                                     Fragment    NaN
#
#                                                   author  rating language  \
# 10912             Hugh Behm-Steinberg (Goodreads Author)    4.70  English
# 10913  Bernie Morris (Goodreads Author), Linda Kopers...    4.85  English
# 10914                                         Lars Norén    3.39  Swedish
#
#            genres  pages               publisher  publish year  numRatings  \
# 10912  ['Poetry']    116           No Tell Books          2007          33
# 10913  ['Poetry']    124        Bronwyn Editions          2009          33
# 10914  ['Poetry']    541  Albert Bonniers Förlag          2015          23
#
#        likedPercent price
# 10912           100  13.1
# 10913           100  2.48
# 10914            83   NaN

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" size=5>
#
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# <strong>Info</strong>: خلاصه دادگان را نمایش دهید. با استفاده از همین اطلاعات کلی خواهید دید که نوع یکی از ستون‌های داده به درستی تنظیم نشده است و در ادامه برایمان مشکل‌ساز خواهد شد. آیا می‌توانید حدس بزنید کدام ستون؟
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۱ امتیاز</span>
# </font>
# </div>

# %%
# code here
dataframe.info()
# price should be int64
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10915 entries, 0 to 10914
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         10915 non-null  object
#  1   series        5574 non-null   object
#  2   author        10915 non-null  object
#  3   rating        10915 non-null  float64
#  4   language      10915 non-null  object
#  5   genres        10915 non-null  object
#  6   pages         10915 non-null  int64
#  7   publisher     10915 non-null  object
#  8   publish year  10915 non-null  int64
#  9   numRatings    10915 non-null  int64
#  10  likedPercent  10915 non-null  int64
#  11  price         8960 non-null   object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 1023.4+ KB

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# <strong>Numerical و Categorial(عددی و دسته‌بندی):</strong>  با توجه به شهودی که تاکنون از مجموعه داده‌ها بدست آورده‌اید، لیستی از ستون‌های Numerical و Categorial تعریف و چاپ کنید. (به ترتیب، متغیر‌ها را با همین نام‌‌ها، نام‌گذاری کنید)
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۱ امتیاز</span>
# </font>
# </div>

# %%
# code here
Numberical=dataframe[['rating','pages','publish year','numRatings','likedPercent','price']]
Categorial=dataframe[['title','series','author','language','genres','publisher']]
print(Numberical)
print(Categorial)
# Out:
#        rating  pages  publish year  numRatings  likedPercent price
# 0        4.33    374          2008     6376780            96  5.09
# 1        4.50    870          2004     2507623            98  7.38
# 2        4.28    324          2006     4501075            95   NaN
# 3        4.26    279          2000     2998241            94   NaN
# 4        3.60    501          2006     4964519            78   2.1
# ...       ...    ...           ...         ...           ...   ...
# 10910    3.52    123          2002          21            86   6.9
# 10911    3.66    224          2000          44            91  3.37
# 10912    4.70    116          2007          33           100  13.1
# 10913    4.85    124          2009          33           100  2.48
# 10914    3.39    541          2015          23            83   NaN
#
# [10915 rows x 6 columns]
#                                              title                 series  \
# 0                                 The Hunger Games    The Hunger Games #1
# 1        Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                            To Kill a Mockingbird  To Kill a Mockingbird
# 3                              Pride and Prejudice                    NaN
# 4                                         Twilight   The Twilight Saga #1
# ...                                            ...                    ...
# 10910                            The Wedding Dress                    NaN
# 10911                                    The Spurs       Golden Armour #3
# 10912                             Shy Green Fields                    NaN
# 10913  An A - Z of Looney Limericks (for big kids)                    NaN
# 10914                                     Fragment                    NaN
#
#                                                   author language  \
# 0                                        Suzanne Collins  English
# 1              J.K. Rowling, Mary GrandPré (Illustrator)  English
# 2                                             Harper Lee  English
# 3              Jane Austen, Anna Quindlen (Introduction)  English
# 4                                        Stephenie Meyer  English
# ...                                                  ...      ...
# 10910                                     Gary E. Parker  English
# 10911                                      Richard Brown  English
# 10912             Hugh Behm-Steinberg (Goodreads Author)  English
# 10913  Bernie Morris (Goodreads Author), Linda Kopers...  English
# 10914                                         Lars Norén  Swedish
#
#                                                   genres  \
# 0      ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1      ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 2      ['Classics', 'Fiction', 'Historical Fiction', ...
# 3      ['Classics', 'Fiction', 'Romance', 'Historical...
# 4      ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# ...                                                  ...
# 10910                                        ['Fiction']
# 10911                                        ['Fantasy']
# 10912                                         ['Poetry']
# 10913                                         ['Poetry']
# 10914                                         ['Poetry']
#
#                               publisher
# 0                      Scholastic Press
# 1                       Scholastic Inc.
# 2      Harper Perennial Modern Classics
# 3                        Modern Library
# 4             Little, Brown and Company
# ...                                 ...
# 10910                            Victor
# 10911                        Scholastic
# 10912                     No Tell Books
# 10913                  Bronwyn Editions
# 10914            Albert Bonniers Förlag
#
# [10915 rows x 6 columns]

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# <strong>Describe</strong>: بدیهی است که برخی ویژگی‌ها فقط برای ستون‌های عددی تعریف می‌شود و برعکس. (برخی فقط برای ستون‌های Categorial) برخی از این ویژگی‌های مهم آماری، میانگین، کمینه و بیشینه و چارک‌ها هستند. خلاصه اطلاعات آماری دیتاست را چاپ کنید به نحوی که هر ستون، مربوط به یکی از مشخصه‌های آماری (مثل mean، std  و ..) باشد.
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۱ امتیاز</span>
# </font>
# </div>

# %%
# code here
Numberical.describe()
#where is price?
# Out:
#              rating         pages  publish year    numRatings  likedPercent
# count  10915.000000  10915.000000  10915.000000  1.091500e+04  10915.000000
# mean       4.040307    375.408887   1998.673019  6.774692e+04     92.536051
# std        0.269764    285.430525     27.219174  2.198857e+05      4.890037
# min        1.900000      0.000000   1905.000000  2.000000e+00     27.000000
# 25%        3.870000    248.000000   2000.000000  6.788500e+03     91.000000
# 50%        4.050000    336.000000   2006.000000  2.015400e+04     94.000000
# 75%        4.220000    434.000000   2012.000000  5.335050e+04     96.000000
# max        5.000000   8258.000000   2020.000000  7.048471e+06    100.000000

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# احتمالا متوجه شده‌اید که در خروجی بالا یکی از ستون‌ها بررسی نشده است. پیشتر به دلیل این موضوع اشاره شد. در ادامه (بحث Preprocess) خواهید دید که اصلاح و تمیز‌سازی اطلاعات یکی از مراحل مهم در EDA است.
# <br><br><strong>Unique values</strong>: از آنجایی که پیش‌نمایش و بررسی همه سطر‌های داده بسیار زمان‌بر است، برای بررسی اینکه در هر ستون به طور کلی چه مقادیری قرار دارند (به خصوص در ستون‌های Categorial) باید به بررسی مقادیر یکتا بپردازیم.
# <br>
# دیتافریمی بسازید که دارای دو ستون با نام‌های unique counts و null count باشد.
#     به ازای هر ستون از دیتافریم books، یک سطر ایجاد کنید و دو مقدار بالا را برای آن‌ّ محاسبه کنید. (اولین ستون تعداد مقادیر یکتا و دومین ستون، تعداد موارد Null است)
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۳ امتیاز</span>
# </font>
# </div>

# %%
# code here
uniqueValues=dataframe.nunique()
nullValues=dataframe.isnull().sum()
new={'unique counts':uniqueValues,'null count':nullValues}
new_dataframe=pd.DataFrame(new)
print(new_dataframe)
# Out:
#               unique counts  null count
# title                 10673           0
# series                 5512        5341
# author                 6135           0
# rating                  199           0
# language                 43           0
# genres                 9375           0
# pages                  1037           0
# publisher              2962           0
# publish year             72           0
# numRatings             9376           0
# likedPercent             47           0
# price                  1851        1955

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# با توجه به خروجی بالا و فهمی که از کلیت داده بدست آورده‌اید، ستون‌هایی (حداقل سه ستون) که دانستن مقادیر یکتای آن کاربردی خواهد بود را انتخاب کنید و مقادیر یکتایش را در یک متغیر نگه‌داری کنید. (در ادامه از این        لیست استفاده خواهد شد)
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۳ امتیاز</span>
# </font>
# </div>

# %%
# code here
uniqueYear=dataframe['publish year'].unique().tolist()
uniqueLanguage=dataframe['language'].unique().tolist()
uniquePublisher=dataframe['publisher'].unique().tolist()
uniqueval=[]
uniqueval.append(uniqueYear)
uniqueval.append(uniqueLanguage)
uniqueval.append(uniquePublisher)
#print(uniqueval)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
#
# <font face="Estedad Semibold" color=black size=5>
# تمیزسازی داده
# </font>
#
# <br>
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# تا اینجا شهود کلی‌ای از دیتاست کتاب‌ها بدست آورده‌ایم. اما پیش از آنکه بخواهیم فرضیه‌ها و استدلالات خود را درباره ارتباط بین ویژگی‌های این دادگان و تحلیل آن‌ها بیان کنیم لازم است داده‌ها را تمیز کنیم. در ادامه به گام‌ّهای مختلف این موضوع خواهیم پرداخت:</font>
# <br><br>
# <font face="Estedad Semibold" color=black size=5>
# داده تکراری
# </font>
#
# <br>
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# از آنجایی که داده‌های تکراری می‌توانند تحلیل ما را اریبی کنند،‌ باید سطر‌های تکراری را حذف ‌کنیم. در دیتافریم books، کتاب‌هایی که دارای عنوان مشابه هستند را حذف کنید و تعداد سطر‌های حذف شده را نیز پرینت کنید.
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۱ امتیاز</span>
# </font>
#
# </div>

# %%
# code here
notrepeated=dataframe.drop_duplicates(subset = "title")
count=rows-notrepeated.shape[0]
print(count)
# Out:
# 242

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# احتمالا حدس زده باشید که صرف عنوان کتاب‌ها برای کشف داده تکراری معیار مناسبی نیست! (چرا؟) سعی کنید با توجه به درک خودتان، ستون‌های دیگری را نیز معیار قرار دهید و چنانچه سطر تکراری کشف شد، آخرین سطر از سطور تکراری را نگه‌داشته و باقی موارد را حذف کنید. (توجه کنید که خروجی این قسمت نباید درون یک متغیر جدید ریخته شود و باید به صورت inplace انجام شود)
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۲ امتیاز</span>
# </font>
# </div>

# %%
# code here
dataframe=dataframe.drop_duplicates(subset = ["title","author","language"])
print(rows-dataframe.shape[0])
# Out:
# 10

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
#
# <font face="Estedad Semibold" color=black size=5>
# تبدیل نوع
# </font>
#
# <br>
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# همانطور که در قسمت «نیم نگاه» متوجه شدید،‌ یکی از ستون‌های عددی دادگان به صورت رشته ذخیره شده است و این موضوع در ادامه و هنگام انجام عملیات‌های محاسباتی دردسرساز خواهد شد.<br><br>
# نوع این ستون را به نوع عددی تغییر دهید و مقادیری غیرقابل تبدیل را با NA پر کنید.
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۱ امتیاز</span>
# </font>
# </div>

# %%
# code here
dataframe['price']=pd.to_numeric(dataframe['price'], errors='coerce')
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10905 entries, 0 to 10914
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         10905 non-null  object
#  1   series        5565 non-null   object
#  2   author        10905 non-null  object
#  3   rating        10905 non-null  float64
#  4   language      10905 non-null  object
#  5   genres        10905 non-null  object
#  6   pages         10905 non-null  int64
#  7   publisher     10905 non-null  object
#  8   publish year  10905 non-null  int64
#  9   numRatings    10905 non-null  int64
#  10  likedPercent  10905 non-null  int64
#  11  price         8949 non-null   float64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 1.1+ MB

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# هنگام ذخیره داده در قالب csv، نوع‌داده‌ّهای خاص از جمله لیست‌ها به عنوان رشته ذخیره‌ می‌شوند. این موضوع طبیعتا سبب می‌شود که ما از ویژگی‌های متعدد مربوط به این نوع‌داده (لیست) نتوانیم استفاده کنیم.
# <br>
# در دیتافریم books، نوع ستون‌ مربوط به ژانر کتاب را به لیست تبدیل کنید. (راه‌های متعددی برای این کار وجود دارد و تا زمانی که خواسته مسئله برآورده شود راه حل شما قابل قبول است)
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۲ امتیاز</span>
# </font>
# </div>

# %%
# code here
dataframe.genres = dataframe.genres.apply(ast.literal_eval)
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10905 entries, 0 to 10914
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         10905 non-null  object
#  1   series        5565 non-null   object
#  2   author        10905 non-null  object
#  3   rating        10905 non-null  float64
#  4   language      10905 non-null  object
#  5   genres        10905 non-null  object
#  6   pages         10905 non-null  int64
#  7   publisher     10905 non-null  object
#  8   publish year  10905 non-null  int64
#  9   numRatings    10905 non-null  int64
#  10  likedPercent  10905 non-null  int64
#  11  price         8949 non-null   float64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 1.1+ MB

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# در ادامه، لیست تمام ژانر‌های ممکن را با گرفتن اجتماع روی سطر‌ها بدست آورید و در یک متغیر با نام مناسب ذخیره کنید. سپس تعداد این ژانر‌ها را نیز چاپ کنید.
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۲ امتیاز</span>
# </font>
#
# </div>

# %%
# code here
unique={}
for i in dataframe['genres']:
    unique=set(list(unique)+i)
print(len(unique))
# Out:
# 679

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# برای بررسی بهتر میزان تعدد ژانر‌های مختلف، دیتافریمی بسازید که تعداد تکرر هر ژانر را نشان دهد.  سپس  ۱۰ ژانر با بیشترین تکرار را چاپ کنید.
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۲ امتیاز</span>
# </font>
# </div>

# %%
# code here
uniqueGenre={}
for i in unique:
    number=0
    for j in dataframe.genres:
        number+=j.count(i)
    uniqueGenre[i]=number
sorted_uniqueGenre=sorted(uniqueGenre.items(), key=lambda x:x[1], reverse=True)
print(sorted_uniqueGenre[0:10])
# Out:
# [('Fiction', 8353), ('Fantasy', 4369), ('Romance', 3681), ('Young Adult', 3391), ('Novels', 2540), ('Contemporary', 2419), ('Classics', 2366), ('Audiobook', 2293), ('Adult', 2242), ('Historical Fiction', 2042)]

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# فرض کنید بخواهیم کتاب‌ها را بر اساس نویسندگان دسته‌بندی کنیم و در مورد هر نویسنده، میانگین امتیازی که کتاب‌هایش گرفته است را به عنوان معیار حرفه‌ای بودن آن نویسنده در نظر بگیریم. اما چالشی وجود دارد. اگر داده را بر اساس ستون نام نویسنده گروه‌بندی کنیم خواهیم دید که دو کتاب Harry Potter #1 و #7، در دو دسته جداگانه قرار خواهند گرفت، در حالیکه هر دو برای یک نویسنده هستند. (چرا؟)
#
# <br>
# به جهت جلوگیری از پیچیدگی بیشتر، فقط نام اولین نویسنده را نگه دارید و باقی نویسندگان و یا طراحان را حذف کنید. در نهایت باید ستون نویسندگان فقط شامل  یک نام باشد.
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۲ امتیاز</span>
# </font>
#
# </div>

# %%
# code here
authorsuni = []
for author in dataframe['author']:
    authorsuni.append(author.split(',')[0])
dataframe['author'] = authorsuni
uniqueAuthor=dataframe['author'].unique().tolist()
authorsrate={}
count={}
sum={}
for i in uniqueAuthor:
    sum[i]=0
    count[i]=0
for j in range(dataframe.shape[0]):
    sum[dataframe.iloc[j]['author']]=sum[dataframe.iloc[j]['author']]+dataframe.iloc[j]['rating']
    count[dataframe.iloc[j]['author']]=count[dataframe.iloc[j]['author']]+1
for i in uniqueAuthor:
    authorsrate[i]=sum[i]/count[i]
print(authorsrate)
# Out:
# {'Suzanne Collins': 4.218181818181818, 'J.K. Rowling': 4.434117647058824, 'Harper Lee': 3.795, 'Jane Austen': 4.104285714285714, 'Stephenie Meyer': 3.807, 'Markus Zusak (Goodreads Author)': 4.21, 'George Orwell': 4.025, 'C.S. Lewis': 4.085333333333334, 'J.R.R. Tolkien': 4.24, 'Margaret Mitchell': 4.3, 'John Green (Goodreads Author)': 3.95125, 'Douglas Adams': 4.151999999999999, 'Shel Silverstein': 4.297142857142857, 'Emily Brontë': 3.86, 'Dan Brown (Goodreads Author)': 3.794285714285714, 'Arthur Golden': 4.12, 'Oscar Wilde': 4.194166666666667, 'Lewis Carroll': 4.078, 'Charlotte Brontë': 3.88, 'Victor Hugo': 4.1075, 'Ray Bradbury': 4.061111111111111, 'Veronica Roth (Goodreads Author)': 4.1121428571428575, 'William Golding': 3.69, 'William Shakespeare': 3.878636363636363, 'Paulo Coelho (Goodreads Author)': 3.5975, 'Fyodor Dostoyevsky': 4.136, 'Stephen Chbosky': 4.2, 'F. Scott Fitzgerald': 3.874, 'Cassandra Clare (Goodreads Author)': 4.3039999999999985, 'Orson Scott Card': 3.8825000000000003, 'Kathryn Stockett (Goodreads Author)': 4.47, 'L.M. Montgomery': 4.1692857142857145, 'Antoine de Saint-Exupéry': 4.115, 'E.B. White': 4.05, 'John Steinbeck': 3.986363636363636, 'Audrey Niffenegger (Goodreads Author)': 3.615, 'Bram Stoker': 4.0, 'Aldous Huxley': 3.9433333333333334, 'Gabriel García Márquez': 3.882, 'J.D. Salinger': 4.02, 'William Goldman': 4.26, 'Rick Riordan (Goodreads Author)': 4.32125, 'Frances Hodgson Burnett': 4.165, 'Khaled Hosseini (Goodreads Author)': 4.243333333333333, "Madeleine L'Engle": 4.067777777777779, 'George R.R. Martin': 4.242105263157894, 'Mark Twain': 3.920833333333334, 'Alice Sebold': 3.8, 'S.E. Hinton (Goodreads Author)': 3.936666666666666, 'Maurice Sendak': 4.22, 'Dr. Seuss': 4.1525, 'Homer': 3.893333333333333, 'Yann Martel': 3.535, 'Charles Dickens': 3.9252941176470584, 'Sara Gruen (Goodreads Author)': 4.09, 'Vladimir Nabokov': 4.0128571428571425, 'Kurt Vonnegut Jr.': 3.9935714285714283, 'Mary Wollstonecraft Shelley': 3.81, 'Margaret Atwood (Goodreads Author)': 3.9569230769230774, 'Lois Lowry (Goodreads Author)': 3.9457142857142857, 'Joseph Heller': 3.755, 'Frank Herbert': 3.9675, 'Ken Follett (Goodreads Author)': 4.15, 'Stephen King (Goodreads Author)': 3.9995081967213117, 'Arthur Conan Doyle': 4.239333333333333, 'Richard Adams': 4.06, 'Louisa May Alcott': 3.9966666666666666, 'Sylvia Plath': 4.156000000000001, 'Ken Kesey': 4.1850000000000005, 'Leo Tolstoy': 4.066666666666666, 'Diana Gabaldon (Goodreads Author)': 4.29, 'Jodi Picoult (Goodreads Author)': 3.8736363636363644, 'Roald Dahl': 4.095882352941177, 'Stieg Larsson': 4.27, 'Daphne du Maurier': 3.9720000000000004, 'Alice Walker': 4.116666666666666, 'Betty Smith': 4.085, 'Anthony Burgess': 3.9500000000000006, 'Cormac McCarthy': 4.0760000000000005, 'Frank McCourt': 3.8533333333333335, 'Richelle Mead (Goodreads Author)': 4.198, 'Hermann Hesse': 4.024285714285715, 'Barbara Kingsolver': 3.9828571428571427, 'Philip Pullman': 4.01625, 'Miguel de Cervantes Saavedra': 3.9, 'Ayn Rand': 3.724, 'Ernest Hemingway': 3.8800000000000003, 'Nicholas Sparks (Goodreads Author)': 4.025714285714285, 'A.A. Milne': 4.3914285714285715, 'Edgar Allan Poe': 4.154999999999999, 'Anne Rice': 3.815, 'John Irving (Goodreads Author)': 3.817, 'Herman Melville': 3.54, 'Anita Diamant (Goodreads Author)': 4.18, 'Sue Monk Kidd (Goodreads Author)': 3.8233333333333337, 'Agatha Christie': 3.938888888888888, 'Jeffrey Eugenides': 3.7600000000000002, 'Albert Camus': 4.09375, 'Mikhail Bulgakov': 4.195, 'Patrick Rothfuss (Goodreads Author)': 4.33, 'Christopher Paolini (Goodreads Author)': 4.152857142857143, 'Jack Kerouac': 3.8466666666666662, 'Franz Kafka': 3.9699999999999998, 'Carlos Ruiz Zafón': 4.014285714285713, 'Mark Haddon': 3.88, 'Eric Carle': 4.3, 'Mitch Albom (Goodreads Author)': 4.04, 'Milan Kundera': 3.9771428571428573, 'Umberto Eco': 3.818, 'Wilson Rawls': 4.0600000000000005, 'Mario Puzo': 3.9975, 'Nathaniel Hawthorne': 3.43, 'Truman Capote': 3.9875, 'Chuck Palahniuk (Goodreads Author ...

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="Estedad" size=4 color=#2d2d2e>
# <div style="margin: 10px 0; border-radius: 8px;padding: 15px; background-color: #3ccfaa; color: white; ">
#     تا اینجا کارای مختلفی انجام دادیم و علاوه بر تمیز سازی دیتا یه سری کارای جانبی هم انجام دادیم. اما دیگه می‌خوایم بریم سراغ بخش جذاب کار که همون بصری سازیه. خوبه اشاره کنیم که این مرحله آخر به نوعی ویترین تمام مراحل گذشته است و اگر یک مهندس علم داده نتونه  کارایی که کرده رو با رسم شکل توضیح بده، احتمالا زبون مشترکی با مدیران و تصمیم‌گیران نهایی نخواهد داشت!
#         </div>
# </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
#  <font face="Estedad Semibold" size=5>
#
# <font color=black size=5>
# تحلیل به همراه بصری‌سازی
# </font>
#
# <br>
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# در این قسمت به تحلیل‌ّهای چالشی‌تر خواهیم پرداخت و در نهایت نتیجه هر تحلیل را نیز به صورت بصری نمایش می‌دهیم.
# <br>
# یادآوری می‌کنیم که برای رسم نمودار و موارد دیگر، لزومی به استفاده از کتابخانه‌های خاصی نیست و انتخاب آن به دلخواه فرد خواهد بود. (استفاده از کتاب‌خانه matplotlib به جهت گستردگی کاربرد توصیه می‌شود)
# <br><br>
# با استفاده از نمودار pie، نسبت کتاب‌های چند‌جلدی به تک‌جلدی را نمایش دهید.
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۳ امتیاز</span>
# </font>
# </font>
# </div>

# %%
# code here
numberofnonseries=nullValues['series']
numberofseries=dataframe.shape[0]-numberofnonseries
plt.pie([numberofseries,numberofnonseries],labels=["number of books in a series","number of solo books"])
plt.show()

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# برای ۶ زبانی که بیشترین تعداد کتاب را دارند نمودار pie ترسیم کنید.
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۲ امتیاز</span>
# </font>
# </div>

# %%
# code here
keyval={}
for i in uniqueLanguage:
    #print(i)
    keyval[i]=dataframe['language'].value_counts()[i]
    #values.append(dataframe[i].value_counts())
sorted_uniqueLanguage=sorted(keyval.items(), key=lambda x:x[1], reverse=True)
sorted_uniqueLanguagesub=dict(sorted_uniqueLanguage[0:6])
plt.pie(list(sorted_uniqueLanguagesub.values()),labels=list(sorted_uniqueLanguagesub.keys()))
plt.show()

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# برای فرکانس ژانر‌ها که پیش‌تر محاسبه کردید نمودار ابر واژگان بکشید. (word cloud)
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۳ امتیاز</span>
# </font>
# </div>

# %%
# code here
wc = WordCloud(background_color="white",width=2000,height=2000, max_words=100,relative_scaling=0.5,normalize_plurals=False).generate_from_frequencies(dict(sorted_uniqueGenre))
plt.imshow(wc)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# برای فرکانس زبان‌ها که پیش‌تر محاسبه کردید نمودار ابر واژگان بکشید. (word cloud)
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۲ امتیاز</span>
# </font>
# </div>

# %%
# code here
wc = WordCloud(background_color="white",width=2000,height=2000, max_words=20,relative_scaling=0.5,normalize_plurals=False).generate_from_frequencies(dict(sorted_uniqueLanguage))
plt.imshow(wc)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# تعداد کتاب‌های نوشته شده به هر زبان را در یک نمودار میله‌ای افقی به صورت مرتب شده (نزولی) نشان دهید.
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۳ امتیاز</span>
# </font>
# </div>

# %%
# code here
plt.bar(list(dict(sorted_uniqueLanguagesub).keys()),list(dict(sorted_uniqueLanguagesub).values()),color='maroon',width=1)
plt.xlabel("Languages")
plt.ylabel("No. of books offered")
plt.title("Books in different languages")
plt.show()
#only first 6 are shown because otherwise it would be ugly

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
#
# <div dir = "rtl" style="direction:rtl;line-height:200%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# می‌خواهیم بررسی اجمالی روی محبوب‌ترین نویسنده داشته باشیم. برای این منظور، لازم است گام‌های زیر را طی کنیم:
# <br><br>
# <div style="margin: 10px 0; border-radius: 8px;padding: 15px; background-color: #fff2b2; color: #7c620c; ">
# توجه کنید که هر گام باید طی شود و مسئله لزوما جواب یکتا ندارد. در نهایت بر اساس همین گام‌ها نمره‌دهی خواهد شد
# </div>
#
# <ul>
# <li>کتاب‌هایی که تعداد رای کمتری از میزان threshold دارند را از دادگان کنار بگذاریم. (این threshold  را شما به طور معقول تعیین کنید. خلاقیت شما در تعیین آن اهمیت دارد، لذا دلیل انتخابتان را به طور کوتاه شرح دهید)
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۳ امتیاز</span>
# </li>
# </ul>
#     </font>
# </div>

# %%
# code here
threshhold=dataframe['numRatings'].mean()
dataframe = dataframe[dataframe['numRatings'] > 1.5*math.sqrt(threshhold)]
print(dataframe.shape[0])#number of remaining datas
#a function of expected value is the threshhold because we want the variance to be low while keeping most of the datas. if the distribution of ratings are the same and independent, the limit of their sum will be a normal distribution and by considering the radical of their expected, we will achieve our goal.
# Out:
# 9652

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
#
# <div dir = "rtl" style="direction:rtl;line-height:200%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# <ul>
# <li>
# به عنوان معیار محبوبیت، ستون جدید با نام popularity اضافه کنید و مقدار آن را بر حسب دو ستون rating و likedPercent به صورت وزن‌دار محاسبه کنید. به ترتیب وزن هر یک را 3 و 1 در نظر بگیرید. (مهم: به عدم یکسان نبودن مقیاس دو ستون توجه کنید)
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۴ امتیاز</span>
# </li>
# </ul>
#     </font>
# </div>

# %%
# code here
popularity=[]
for i in range(dataframe.shape[0]):
    popularity.append((dataframe.iloc[i]['rating']*20*3+dataframe.iloc[i]['likedPercent']*1)/4)
dataframe['popularity']=popularity
display(dataframe)
# Out:
#                                            title                   series  \
# 0                               The Hunger Games      The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix          Harry Potter #5
# 2                          To Kill a Mockingbird    To Kill a Mockingbird
# 3                            Pride and Prejudice                      NaN
# 4                                       Twilight     The Twilight Saga #1
# ...                                          ...                      ...
# 10883                            Memory in Death             In Death #22
# 10892                                   Timeless  Parasol Protectorate #5
# 10898                                Devil Bones   Temperance Brennan #11
# 10904                               The Nonesuch                      NaN
# 10906                                 Angel Star            Angel Star #1
#
#                                    author  rating language  \
# 0                         Suzanne Collins    4.33  English
# 1                            J.K. Rowling    4.50  English
# 2                              Harper Lee    4.28  English
# 3                             Jane Austen    4.26  English
# 4                         Stephenie Meyer    3.60  English
# ...                                   ...     ...      ...
# 10883        J.D. Robb (Goodreads Author)    4.33  English
# 10892    Gail Carriger (Goodreads Author)    4.12  English
# 10898     Kathy Reichs (Goodreads Author)    3.90  English
# 10904                     Georgette Heyer    4.05  English
# 10906  Jennifer Murgia (Goodreads Author)    3.28  English
#
#                                                   genres  pages  \
# 0      [Young Adult, Fiction, Dystopia, Fantasy, Scie...    374
# 1      [Fantasy, Young Adult, Fiction, Magic, Childre...    870
# 2      [Classics, Fiction, Historical Fiction, School...    324
# 3      [Classics, Fiction, Romance, Historical Fictio...    279
# 4      [Young Adult, Fantasy, Romance, Vampires, Fict...    501
# ...                                                  ...    ...
# 10883  [Mystery, Romance, Crime, Fiction, Romantic Su...    375
# 10892  [Steampunk, Fantasy, Paranormal, Romance, Vamp...    386
# 10898  [Mystery, Crime, Fiction, Thriller, Mystery Th...    310
# 10904  [Romance, Historical Fiction, Regency, Histori...    304
# 10906  [Young Adult, Angels, Fantasy, Paranormal, Rom...    251
#
#                               publisher  publish year  numRatings  \
# 0                      Scholastic Press          2008     6376780
# 1                       Scholastic Inc.          2004     2507623
# 2      Harper Perennial Modern Classics          2006     4501075
# 3                        Modern Library          2000     2998241
# 4             Little, Brown and Company          2006     4964519
# ...                                 ...           ...         ...
# 10883                     Berkley Books          2006       25958
# 10892                             Orbit          2012       28209
# 10898             Scribner Book Company          2008       25996
# 10904                             Arrow          2005        9220
# 10906         Lands Atlantic Publishing          2010        1770
#
#        likedPercent  price  popularity
# 0                96   5.09       88.95
# 1                98   7.38       92.00
# 2                95    NaN       87.95
# 3                94    NaN       87.40
# 4                78   2.10       73.50
# ...             ...    ...         ...
# 10883            98   4.03       89.45
# 10892            96   3.49       85.80
# 10898            94   2.77       82.00
# 10904            96   3.75       84.75
# 10906            71   5.21       66.95
#
# [9652 rows x 13 columns]

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
#
# <div dir = "rtl" style="direction:rtl;line-height:200%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
#
# <ul>
# <li>
# در نهایت کتاب‌ّها را بر اساس نام نویسنده دسته بندی کنید، به طوریکه در هر سطر اطلاعات زیر در مورد آن نویسنده وجود داشته باشد:
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۱۰ امتیاز</span>
# <ul>
# <li>نام نویسنده</li>
# <li>تعداد کتاب‌ها</li>
# <li>مجموع صفحات نوشته‌شده</li>
# <li>تعداد انتشارات متمایزی که با آنها کار کرده است</li>
# <li>سال انتشار اولین کتاب</li>
# <li>لیست ۳ ژانری که نویسنده بیشترین کتاب‌ها را در آن‌ّها نوشته است.</li>
# <li>میانگین میزان محبوبیت</li>
# <li>مجموع تعداد رای‌ها</li>
# </ul>
#
# </li>
# </ul>
#     </font>
# </div>

# %%
# code here
authornames=dataframe['author'].unique().tolist()
uniquegenres=unique
numberofbooks={}
numberofpages={}
numberofpublishers={}
publishers={}
firstyear={}
mostworkedgenre={}
avgpop={}
sumvotes={}
topthreegenre={}
for i in authornames:
    numberofbooks[i]=0
    numberofpages[i]=0
    publishers[i]=set()
    numberofpublishers[i]=0
    firstyear[i]=3000
    mostworkedgenre[i]=dict.fromkeys(uniquegenres, 0)
    topthreegenre[i]=list()
    avgpop[i]=0
    sumvotes[i]=0
for i in range(dataframe.shape[0]):
    j=dataframe.iloc[i]['author']
    numberofbooks[j]+=1
    numberofpages[j]+=dataframe.iloc[i]['pages']
    firstyear[j]=min(firstyear[j],dataframe.iloc[i]['publish year'])
    avgpop[j]+=dataframe.iloc[i]['popularity']
    sumvotes[j]+=dataframe.iloc[i]['numRatings']
    publishers[j].add(dataframe.iloc[i]['publisher'])
    for k in dataframe.iloc[i]['genres']:
        mostworkedgenre[j][k]+=1
for i in authornames:
    avgpop[i]=avgpop[i]/numberofbooks[i]
    numberofpublishers[i]=len(publishers[i])
    sortgenre = sorted(mostworkedgenre[i], key = mostworkedgenre[i].get, reverse = True)
    topthreegenre[i].extend(sortgenre[0:3])
newdata={}
newdata['avg popularity']=avgpop
newdata['sum of votes']=sumvotes
newdata['first year']=firstyear
newdata['number of publishers']=numberofpublishers
newdata['number of pages']=numberofpages
newdata['number of books']=numberofbooks
newdata['top 3 genres']=topthreegenre
newdataframe=pd.DataFrame(newdata)
display(newdataframe)
# Out:
#                                     avg popularity  sum of votes  first year  \
# Suzanne Collins                          87.136364      11836703        2005
# J.K. Rowling                             90.482353      24187968        1905
# Harper Lee                               78.675000       4733401        2006
# Jane Austen                              84.957143       5744175        1996
# Stephenie Meyer                          78.180000      10464881        2006
# ...                                            ...           ...         ...
# Rosie Harris                             86.400000          1102        2006
# Anna Kendrick                            81.700000         77367        2016
# Olivia Ardey                             80.300000           794        2013
# صبري موسى                                81.250000          1067        1905
# Jennifer Murgia (Goodreads Author)       66.950000          1770        2010
#
#                                     number of publishers  number of pages  \
# Suzanne Collins                                        3             4526
# J.K. Rowling                                          11            18243
# Harper Lee                                             2              602
# Jane Austen                                            5             3494
# Stephenie Meyer                                        4             8894
# ...                                                  ...              ...
# Rosie Harris                                           1              368
# Anna Kendrick                                          1              275
# Olivia Ardey                                           1              331
# صبري موسى                                              1              223
# Jennifer Murgia (Goodreads Author)                     1              251
#
#                                     number of books  \
# Suzanne Collins                                  11
# J.K. Rowling                                     17
# Harper Lee                                        2
# Jane Austen                                       7
# Stephenie Meyer                                  10
# ...                                             ...
# Rosie Harris                                      1
# Anna Kendrick                                     1
# Olivia Ardey                                      1
# صبري موسى                                         1
# Jennifer Murgia (Goodreads Author)                1
#
#                                                                     top 3 genres
# Suzanne Collins                                [Young Adult, Adventure, Fantasy]
# J.K. Rowling                                     [Fantasy, Fiction, Young Adult]
# Harper Lee                          [Literature, Historical, Historical Fiction]
# Jane Austen                         [Literature, Historical, Historical Fiction]
# Stephenie Meyer                               [Young Adult, Paranormal, Romance]
# ...                                                                          ...
# Rosie Harris                                      [Fiction, Fandom, Fairy Tales]
# Anna Kendrick                                            [Adult, Memoir, Comedy]
# Olivia Ardey                                      [Romance, Fandom, Fairy Tales]
# صبري موسى                                          [Novels, Fandom, Fairy Tales]
# Jennifer Murgia (Goodreads Author)       [Young Adult, Supernatural, Paranormal]
#
# [4176 rows x 7 columns]

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
#
# <div dir = "rtl" style="direction:rtl;line-height:200%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# <ul>
# <li>
# اطلاعات بدست آمده را بر اساس میزان محبوبیت  مرتب کنید (نزولی) و ۱۰ سطر ابتدایی آن را نمایش دهید.
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۲ امتیاز</span>
# </li>
# </ul>
#
# </font>
# </div>

# %%
# code here
newdataframe=newdataframe.sort_values(by='avg popularity',ascending=False)
display(newdataframe[0:10])
# Out:
#                                          avg popularity  sum of votes  \
# Mustafa Kemal Atatürk                         96.350000          3658
# Quino                                         96.150000          8069
# Odysseus Elytis                               96.000000          1768
# Bill Watterson                                95.417857        511874
# Chanel Miller                                 95.400000         55887
# Ramdhari Singh 'Dinkar'                       95.150000          2052
# Neil Gaiman (Goodreads Author) (Writer)       95.116667         22156
# Gary Larson                                   94.950000          6458
# Don Rosa                                      94.800000          3527
# Kalki                                         94.750000          7418
#
#                                          first year  number of publishers  \
# Mustafa Kemal Atatürk                          1905                     1
# Quino                                          2004                     1
# Odysseus Elytis                                1997                     1
# Bill Watterson                                 1905                     5
# Chanel Miller                                  2019                     1
# Ramdhari Singh 'Dinkar'                        1905                     1
# Neil Gaiman (Goodreads Author) (Writer)        2007                     1
# Gary Larson                                    2003                     1
# Don Rosa                                       2005                     1
# Kalki                                          1905                     1
#
#                                          number of pages  number of books  \
# Mustafa Kemal Atatürk                                610                1
# Quino                                                660                1
# Odysseus Elytis                                       40                1
# Bill Watterson                                      3676               14
# Chanel Miller                                        368                1
# Ramdhari Singh 'Dinkar'                              176                1
# Neil Gaiman (Goodreads Author) (Writer)             1840                3
# Gary Larson                                         1272                1
# Don Rosa                                             266                1
# Kalki                                               1452                1
#
#                                                                        top 3 genres
# Mustafa Kemal Atatürk                             [Literature, Politics, Biography]
# Quino                                                   [Comedy, Comics, Childrens]
# Odysseus Elytis                                   [Literature, Nobel Prize, Poetry]
# Bill Watterson                                          [Comedy, Comics, Childrens]
# Chanel Miller                                                [Adult, Memoir, Crime]
# Ramdhari Singh 'Dinkar'                       [Poetry, Indian Literature, Classics]
# Neil Gaiman (Goodreads Author) (Writer)                [Comics, Comic Book, Horror]
# Gary Larson                                                 [Comedy, Comics, Humor]
# Don Rosa                                                 [Comics, Childrens, Humor]
# Kalki                                    [Indian Literature, Adventure, Historical]

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
#
# <div dir = "rtl" style="direction:rtl;line-height:200%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# <ul>
# <li>
# برای ۱۰ نویسنده برتر، نمودارهای زیر را بکشید:
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۶ امتیاز</span>
# <ul>
# <li>نمودار تعداد کتاب‌های نوشته شده (ترتیب اسامی نویسنگان باید به همان صورت مرتب شده میزان محبوبیت باشد)</li>
# <li>نمودار تعداد انتشارات همکار با نویسنده</li>
# <li>نمودار تعداد صفحات کتاب نوشته شده</li>
# </ul>
#
# </li>
# </ul>
#     </font>
# </div>

# %%
# code here
topten=newdataframe[0:10]
ax = plt.gca()
topten['number of books'].plot()
plt.xlabel('names')
plt.ylabel('number of books')
plt.show()
topten['number of publishers'].plot(x='names',y='number of publishers')
plt.xlabel('names')
plt.ylabel('number of publishers')
plt.show()
topten['number of pages'].plot(x='names',y='number of pages')
plt.xlabel('names')
plt.ylabel('number of pages')
plt.show()

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# در ادامه میخواهیم به بررسی دلایل محبوبیت کتاب‌ها بپردازیم. تصور کنید که بخواهیم به رابطه‌ای بین مشخصه‌های یک کتاب از جمله نویسنده، ناشر، ژانر، تعداد صفحات و قیمت آن با میزان محبوبیتش دست‌یابیم.
# <ul>
# <li>
# هم‌بستگی بین تعداد صفحات کتاب با میزان محبوبیت آن را با نمودار Scatter نمایش دهید.
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۵ امتیاز</span></li>
# </ul>
# </font>
# </div>

# %%
# code here
plt.scatter(dataframe['pages'],dataframe['popularity'], c ="blue",s = 1)
plt.ylabel("popularity")
plt.xlabel("number of pages")
plt.show()

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
#
# <div dir = "rtl" style="direction:rtl;line-height:200%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# <ul>
# <li>
# به ازای هر ناشر، میانگین rating کتاب‌ها را محاسبه و در نمودار میله‌ای نمایش دهید.
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۳ امتیاز</span>
# </li>
# </ul>
#     </font>
# </div>

# %%
# code here
avgrating={}
count={}
uniquepublisher=dataframe['publisher'].unique().tolist()
for i in uniquepublisher:
    avgrating[i]=0
    count[i]=0
for i in range(dataframe.shape[0]):
    j=dataframe.iloc[i]['publisher']
    avgrating[j]+=dataframe.iloc[i]['rating']
    count[j]+=1
for i in uniquepublisher:
    avgrating[i]=avgrating[i]/count[i]
plt.bar(list(avgrating.keys()),list(avgrating.values()),color='maroon',width=1)
plt.xlabel("publisher's name")
plt.ylabel("average rating")
plt.title("publishers average")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2997 (\N{TAMIL LETTER VA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Matplotlib currently does not support Tamil natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3006 (\N{TAMIL VOWEL SIGN AA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2985 (\N{TAMIL LETTER NNNA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2980 (\N{TAMIL LETTER TA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3007 (\N{TAMIL VOWEL SIGN I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2986 (\N{TAMIL LETTER PA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 3021 (\N{TAMIL SIGN VIRAMA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2965 (\N{TAMIL LETTER KA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2990 (\N{TAMIL LETTER MA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 35611 (\N{CJK UNIFIED IDEOGRAPH-8B1B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 35527 (\N{CJK UNIFIED IDEOGRAPH-8AC7}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 31038 (\N{CJK UNIFIED IDEOGRAPH-793E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2438 (\N{BENGALI LETTER AA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Matplotlib currently does not support Bengali natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2472 (\N{BENGALI LETTER NA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2509 (\N{BENGALI SIGN VIRAMA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2470 (\N{BENGALI LETTER DA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2474 (\N{BENGALI LETTER PA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2494 (\N{BENGALI VOWEL SIGN AA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2476 (\N{BENGALI LETTER BA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2482 (\N{BENGALI LETTER LA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2495 (\N{BENGALI VOWEL SIGN I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2486 (\N{BENGALI LETTER SHA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2480 (\N{BENGALI LETTER RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2488 (\N{BENGALI LETTER SA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2439 (\N{BENGALI LETTER I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2477 (\N{BENGALI LETTER BHA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2503 (\N{BENGALI VOWEL SIGN E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2463 (\N{BENGALI LETTER TTA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2478 (\N{BENGALI LETTER MA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 2465 (\N{BENGALI LETTER DDA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
#
# <div dir = "rtl" style="direction:rtl;line-height:200%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# <ul>
# <li>
# نمودار بالا را در برای کتاب‌های دارای series و کتاب‌های تک‌جلدی به صورت کنار هم (در یک نمودار) ترسیم کنید.
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۴ امتیاز</span>
# </li>
# </ul>
#     </font>
# </div>

# %%
# code here
avgseries={}
avgnonseries={}
countseries={}
countnonseries={}

for i in uniquepublisher:
    avgseries[i]=0
    avgnonseries[i]=0
    countseries[i]=0
    countnonseries[i]=0
for i in range(dataframe.shape[0]):
    k=dataframe.iloc[i]['series']
    j=dataframe.iloc[i]['publisher']
    if not pd.isnull(k):
        avgseries[j]+=dataframe.iloc[i]['rating']
        countseries[j]+=1
    else:
        avgnonseries[j]+=dataframe.iloc[i]['rating']
        countnonseries[j]+=1
for i in uniquepublisher:
    if countseries[i]!=0:
        avgseries[i]/=countseries[i]
    if countnonseries[i]!=0:
        avgnonseries[i]/=countnonseries[i]

#plt.show()
X_axis = np.arange(len(uniquepublisher))
plt.bar(X_axis - 0.2, list(avgseries.values()), 0.4, label = 'series')
plt.bar(X_axis + 0.2, list(avgnonseries.values()), 0.4, label = 'non series')
  
plt.xticks(X_axis, uniquepublisher)
#plt.bar(uniquepublisher, list(avgseries.values()),color='r',width=1)
#plt.bar(uniquepublisher, list(avgnonseries.values()),color='b',width=1)
plt.legend()
plt.show()

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# از مفاهیم مهمی که در تحلیل داده وجود دارد، بحث داده‌های پرت یا outliers هستند. اهمیت این داده‌ها به این دلیل است که در فرایند‌های یادگیری ماشین مشکل ایجاد می‌کنند. یکی از روش‌های کشف این موارد استفاده از boxplot ها می‌باشد. این نمودار به طور کلی بر مبنای چارک‌ها  طراحی شده است که برای بررسی وجود داده‌های پرت بسیار مفید هستند. در ادامه، دو نمودار به ترتیب برای تعداد صفحات کتاب‌ها و همچنین تعداد رای‌های کتاب به تفکیک تک‌جلدی یا چند‌جلدی بودن ترسیم کنید.
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۸ امتیاز</span>
# </font>
# </div>

# %%
# code here
# code here
notnulls = dataframe.loc[dataframe['series'].notnull(), ['pages','numRatings' ]]
notnulls["isnull"]=[False]*notnulls.shape[0]
nulls = dataframe.loc[dataframe['series'].isnull(), ['pages','numRatings' ]]
nulls["isnull"]=[True]*nulls.shape[0]
all = [notnulls, nulls]
alls = pd.concat(all)
x=alls.drop(['numRatings'],1)
y=alls.drop(['pages'],1)
bp=x.boxplot(by ="isnull")
cp=y.boxplot(by ="isnull")
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_25436\3107361770.py:9: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x=alls.drop(['numRatings'],1)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_25436\3107361770.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   y=alls.drop(['pages'],1)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# با توجه یه اینکه اطلاعات مربوط به سال انتشار کتاب‌ها را داریم، بد نیست سیر زمانی میزان تولید کتاب و همچنین تعداد موسسات انتشاراتی و کتاب‌خوانی را در طول تاریخ بررسی کنیم. برای این سه مورد نمودار time series ترسیم کنید. (معیار کتاب‌خوانی را مجموع تعداد نظرات قرار داده شده برای کتاب‌ها در طول یک سال در نظر بگیرید)
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۳ امتیاز</span>
# </font>
# </div>

# %%
# code here
uniqueyears=sorted(dataframe['publish year'].unique().tolist())
booksbyyear={}
publishersbyyear={}
totalvotesbyyear={}
numpub={}
for i in uniqueyears:
    booksbyyear[i]=0
    publishersbyyear[i]=set()
    totalvotesbyyear[i]=0
for i in range(dataframe.shape[0]):
    j=dataframe.iloc[i]['publish year']
    booksbyyear[j]+=1
    publishersbyyear[j].add(dataframe.iloc[i]['publisher'])
    totalvotesbyyear[j]+=dataframe.iloc[i]['numRatings']
for i in uniqueyears:
    numpub[i]=len(publishersbyyear[i])

plt.plot(uniqueyears,numpub.values(),color='b', label='publishers')
plt.show()
plt.plot(uniqueyears,booksbyyear.values(),color='r', label='books')
plt.show()
plt.plot(uniqueyears,totalvotesbyyear.values(),color='g', label='book reading')
plt.show()

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
#
# <div dir = "rtl" style="direction:rtl;line-height:200%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# مشابه اقدامات بالا را می‌خواهیم در مورد ژانر‌های مختلف انجام دهیم. برای این منظور، لازم است گام‌های زیر را طی کنیم. اما پیش از آغاز به این فکر کنید که آیا این بار نیز روش دسته‌بندی روی ستون جواب خواهد داد یا خیر؟
# <br><br>
# <div style="margin: 10px 0; border-radius: 8px;padding: 15px; background-color: #fff2b2; color: #7c620c; ">
# توجه کنید که هر گام باید طی شود و مسئله لزوما جواب یکتا ندارد. در نهایت بر اساس همین گام‌ها نمره‌دهی خواهد شد
# </div>
#
# <ul>
# <li>
# در ابتدا می‌بایست لیست حاوی ژانر‌های کتاب را بشکنیم، به نحوی که در ستون مربوط به آن، فقط یک ژانر وجود داشته باشد. برای این کار لازم است ستون genres را به سطرهای متوالی تبدیل کنیم تا به ازای هر  ژانر، یک سطر جدید ایجاد شود.</li>
# </ul>
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۳ امتیاز</span>
# </font>
# </div>

# %%
# code here
final = dataframe.explode('genres')
display(final)
# Out:
#                   title               series  \
# 0      The Hunger Games  The Hunger Games #1
# 0      The Hunger Games  The Hunger Games #1
# 0      The Hunger Games  The Hunger Games #1
# 0      The Hunger Games  The Hunger Games #1
# 0      The Hunger Games  The Hunger Games #1
# ...                 ...                  ...
# 10906        Angel Star        Angel Star #1
# 10906        Angel Star        Angel Star #1
# 10906        Angel Star        Angel Star #1
# 10906        Angel Star        Angel Star #1
# 10906        Angel Star        Angel Star #1
#
#                                    author  rating language  \
# 0                         Suzanne Collins    4.33  English
# 0                         Suzanne Collins    4.33  English
# 0                         Suzanne Collins    4.33  English
# 0                         Suzanne Collins    4.33  English
# 0                         Suzanne Collins    4.33  English
# ...                                   ...     ...      ...
# 10906  Jennifer Murgia (Goodreads Author)    3.28  English
# 10906  Jennifer Murgia (Goodreads Author)    3.28  English
# 10906  Jennifer Murgia (Goodreads Author)    3.28  English
# 10906  Jennifer Murgia (Goodreads Author)    3.28  English
# 10906  Jennifer Murgia (Goodreads Author)    3.28  English
#
#                        genres  pages                  publisher  publish year  \
# 0                 Young Adult    374           Scholastic Press          2008
# 0                     Fiction    374           Scholastic Press          2008
# 0                    Dystopia    374           Scholastic Press          2008
# 0                     Fantasy    374           Scholastic Press          2008
# 0             Science Fiction    374           Scholastic Press          2008
# ...                       ...    ...                        ...           ...
# 10906      Paranormal Romance    251  Lands Atlantic Publishing          2010
# 10906            Supernatural    251  Lands Atlantic Publishing          2010
# 10906           Urban Fantasy    251  Lands Atlantic Publishing          2010
# 10906                 Fiction    251  Lands Atlantic Publishing          2010
# 10906  Young Adult Paranormal    251  Lands Atlantic Publishing          2010
#
#        numRatings  likedPercent  price  popularity
# 0         6376780            96   5.09       88.95
# 0         6376780            96   5.09       88.95
# 0         6376780            96   5.09       88.95
# 0         6376780            96   5.09       88.95
# 0         6376780            96   5.09       88.95
# ...           ...           ...    ...         ...
# 10906        1770            71   5.21       66.95
# 10906        1770            71   5.21       66.95
# 10906        1770            71   5.21       66.95
# 10906        1770            71   5.21       66.95
# 10906        1770            71   5.21       66.95
#
# [95188 rows x 13 columns]

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
#
# <div dir = "rtl" style="direction:rtl;line-height:200%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# <ul>
# <li>
# کتاب‌ّها را بر اساس ژانر دسته بندی کنید، به طوریکه در هر سطر اطلاعات زیر در مورد آن ژانر وجود داشته باشد:
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۱۰ امتیاز</span>
# <ul>
# <li>نام ژانر</li>
# <li>تعداد کتاب‌ها</li>
# <li>مجموع صفحات نوشته‌شده</li>
# <li>تعداد نویسندگانی که در آن زمینه فعال هستند</li>
# <li>سال انتشار اولین کتاب در این زمینه</li>
# <li>میانگین rating</li>
# <li>مجموع تعداد رای‌ها</li>
# </ul>
#
# </li>
# </ul>
#     </font>
# </div>

# %%
# code here
uniqueGenre=final['genres'].unique().tolist()
numberofbooks={}
totalpages={}
activeauthors={}
firstyear={}
avgrating={}
totalvotes={}
numberofactivewriters={}
for i in uniqueGenre:
    numberofbooks[i]=0
    totalpages[i]=0
    firstyear[i]=3000
    avgrating[i]=0
    totalvotes[i]=0
    activeauthors[i]=set()
for i in range(final.shape[0]):
    j=final.iloc[i]['genres']
    numberofbooks[j]+=1
    avgrating[j]+=final.iloc[i]['rating']
    firstyear[j]=min(firstyear[j],final.iloc[i]['publish year'])
    totalvotes[j]+=final.iloc[i]['numRatings']
    activeauthors[j].add(final.iloc[i]['author'])
    totalpages[j]+=final.iloc[i]['pages']
for i in uniqueGenre:
    avgrating[i]/=numberofbooks[i]
    numberofactivewriters[i]=len(activeauthors[i])
pirshodam={'genre':uniqueGenre, 'number of books':numberofbooks.values(),'average rating':avgrating.values(),
          'first year':firstyear.values(),'total votes':totalvotes.values(),
          'total pages':totalpages.values(),'number of writers in genre':numberofactivewriters.values(),}
#pirshodam['number of books']=numberofbooks
#pirshodam['first year']=firstyear
#pirshodam['total votes']=totalvotes
#pirshodam['total pages']=totalpages
#pirshodam['number of writers in genre']=numberofactivewriters
#pirshodam['average rating']=avgrating
basedige=pd.DataFrame(pirshodam)
display(basedige)
# Out:
#                           genre  number of books  average rating  first year  \
# 0                   Young Adult             3289        4.039900        1905
# 1                       Fiction             8049        4.025991        1905
# 2                      Dystopia              559        3.992308        1905
# 3                       Fantasy             4131        4.065786        1905
# 4               Science Fiction             1382        4.024457        1905
# ..                          ...              ...             ...         ...
# 672                  Visual Art                1        3.830000        1997
# 673  Western Historical Romance                1        4.110000        2005
# 674                     Burundi                1        4.020000        2009
# 675           American Classics                1        4.050000        2006
# 676                   Semiotics                1        4.100000        1905
#
#      total votes  total pages  number of writers in genre
# 0      289695070      1206104                        1347
# 1      651681673      3164133                        3196
# 2       71062710       216807                         308
# 3      337345618      1701300                        1436
# 4      118782803       577029                         604
# ..           ...          ...                         ...
# 672       137669          515                           1
# 673         3898          410                           1
# 674        15141          277                           1
# 675         2665          448                           1
# 676        13158          160                           1
#
# [677 rows x 7 columns]

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
#
# <div dir = "rtl" style="direction:rtl;line-height:200%; textAlign: right">
# <font face="Estedad" size=4 color = 2d2d2e style="textAlign: right">
# <ul>
# <li>
# اطلاعات بدست آمده را هر بار بر اساس  معیار‌های زیر مرتب کنید و نمودارهای میله‌ای حاصل از آن‌هارا در کنار هم به صورت جدولی ۲ در ۳ یا برعکس ترسیم کنید:
# <span style="background-color: #eeeeee; font-size: 1.2rem; padding: 4px 8px; border-radius: 20px;">۱۰ امتیاز</span>
# <ul>
# <li>نام ژانر</li>
# <li>تعداد کتاب‌ها</li>
# <li>مجموع صفحات نوشته‌شده</li>
# <li>تعداد نویسندگانی که در آن زمینه فعال هستند</li>
# <li>میانگین rating</li>
# <li>مجموع تعداد رای‌ها</li>
# </ul>
#
# </li>
# </ul>
#     </font>
# </div>

# %%
# code here
  
basedige=basedige.sort_values("number of books",False)
plt.subplot(2, 3, 1) # index 1
plt.bar(basedige['genre'], basedige["number of books"], color ='maroon',
        width = 0.4)
  
basedige=basedige.sort_values("average rating",False)
plt.subplot(2, 3, 2) # index 1
plt.bar(basedige['genre'], basedige["average rating"], color ='maroon',
        width = 0.4)
  
basedige=basedige.sort_values("total pages",False)
plt.subplot(2, 3, 3) # index 1
plt.bar(basedige['genre'], basedige["total pages"], color ='maroon',
        width = 0.4)
  
basedige=basedige.sort_values("number of writers in genre",False)
plt.subplot(2, 3, 4) # index 1
plt.bar(basedige['genre'], basedige["number of writers in genre"], color ='maroon',
        width = 0.4)

basedige=basedige.sort_values("total votes",False)
plt.subplot(2, 3, 5) # index 1
plt.bar(basedige['genre'], basedige["total votes"], color ='maroon',
        width = 0.4)
  
basedige=basedige.sort_values("first year",False)
plt.subplot(2, 3, 6) # index 1
plt.bar(basedige['genre'], basedige["first year"], color ='maroon',
        width = 0.4)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_25436\339827978.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.sort_values except for the argument 'by' will be keyword-only.
#   basedige=basedige.sort_values("number of books",False)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_25436\339827978.py:8: FutureWarning: In a future version of pandas all arguments of DataFrame.sort_values except for the argument 'by' will be keyword-only.
#   basedige=basedige.sort_values("average rating",False)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_25436\339827978.py:13: FutureWarning: In a future version of pandas all arguments of DataFrame.sort_values except for the argument 'by' will be keyword-only.
#   basedige=basedige.sort_values("total pages",False)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_25436\339827978.py:18: FutureWarning: In a future version of pandas all arguments of DataFrame.sort_values except for the argument 'by' will be keyword-only.
#   basedige=basedige.sort_values("number of writers in genre",False)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_25436\339827978.py:23: FutureWarning: In a future version of pandas all arguments of DataFrame.sort_values except for the argument 'by' will be keyword-only.
#   basedige=basedige.sort_values("total votes",False)
# C:\Users\Asus\AppData\Local\Temp\ipykernel_25436\339827978.py:28: FutureWarning: In a future version of pandas all arguments of DataFrame.sort_values except for the argument 'by' will be keyword-only.
#   basedige=basedige.sort_values("first year",False)
# <BarContainer object of 677 artists>
